# %%
200//100
# Out:
# 2

# %%
a = []

a.extend(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 a = []
# ----> 3 a.extend(1)
#
# TypeError: 'int' object is not iterable

# %%
a
# Out:
# [1, 2]
